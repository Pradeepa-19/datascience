# %%
# %pip install pandas
import pandas as pd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df=pd.read_csv("interactions.csv")
df
# Out:
#                              interaction_id  \
# 0      2ece1c7b-3244-4eeb-8d3e-f1b0cc09f20f
# 1      bef097f8-4624-406a-9168-fc16f6d9db7a
# 2      131590fb-aded-4eb2-b04a-158540271950
# 3      dda794be-afc4-4b8c-9a5c-3594d513f261
# 4      b68f3af4-29d1-4d85-884a-5e585d5d0a4a
# ...                                     ...
# 99995  26a33561-07c2-4a91-8dac-2d8fc075f3ae
# 99996  1ec7360e-a65a-442a-bbcf-83993e9bf84d
# 99997  ffa12d9b-b050-4f00-ae99-e4fb9207f1a6
# 99998  9b1fa3b9-97a8-432d-9cef-98e6170be9fb
# 99999  78d78560-5ead-4442-b6d5-da1f14cab4d1
#
#                                     user_id  \
# 0      8a49a58e-7e31-4616-8ac8-b1472ed4f5d8
# 1      8a49a58e-7e31-4616-8ac8-b1472ed4f5d8
# 2      8a49a58e-7e31-4616-8ac8-b1472ed4f5d8
# 3      8a49a58e-7e31-4616-8ac8-b1472ed4f5d8
# 4      8a49a58e-7e31-4616-8ac8-b1472ed4f5d8
# ...                                     ...
# 99995  c04a0370-0ab8-42d1-81ff-fd5d3acd890b
# 99996  c04a0370-0ab8-42d1-81ff-fd5d3acd890b
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   interaction_id    100000 non-null  object
#  1   user_id           100000 non-null  object
#  2   product_id        100000 non-null  object
#  3   session_id        100000 non-null  object
#  4   interaction_type  100000 non-null  object
#  5   timestamp         100000 non-null  object
#  6   dwell_time_ms     100000 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
df.describe()
# Out:
#        dwell_time_ms
# count  100000.000000
# mean    17942.900550
# std     21556.684456
# min       500.000000
# 25%      4260.000000
# 50%     11153.000000
# 75%     23342.250000
# max    300000.000000

# %%
df.isnull().sum()
# Out:
# interaction_id      0
# user_id             0
# product_id          0
# session_id          0
# interaction_type    0
# timestamp           0
# dwell_time_ms       0
# dtype: int64

# %%
df['user_id'].nunique()
# Out:
# 6944

# %%
df['product_id'].nunique()
# Out:
# 967

# %%
df['interaction_id'].value_counts()
# Out:
# interaction_id
# 2ece1c7b-3244-4eeb-8d3e-f1b0cc09f20f    1
# e99633dd-05d1-4b08-b497-662f09aa2c63    1
# aa7cf950-203c-4e46-99d1-76e057a12179    1
# 5819113b-9fa7-4674-9083-99f74e733325    1
# 22b0fe1c-6076-4750-bb15-dc190a53dc12    1
#                                        ..
# 6aa1d507-823b-489f-a185-f215c43f702e    1
# c6b9b983-35d9-4dc1-bdff-8fb8c296fc66    1
# e146d4da-0f4a-4aac-808c-0e2556f2dd5d    1
# 1dea4680-3007-4d67-8ba9-009509959eb1    1
# 78d78560-5ead-4442-b6d5-da1f14cab4d1    1
# Name: count, Length: 100000, dtype: int64

# %%
df['dwell_time_ms'].mean()
# Out:
# np.float64(17942.90055)

# %%
df['dwell_time_ms'].median()
# Out:
# 11153.0

# %%
df['dwell_time_ms'].mode()
# Out:
# 0    500
# Name: dwell_time_ms, dtype: int64

# %%
df['dwell_time_ms'].max()
# Out:
# 300000

# %%
df['dwell_time_ms'].min()
# Out:
# 500

# %%
df['session_id'].value_counts()
# Out:
# session_id
# ed5ad937-903d-4b65-99fa-71687a7ea407    28
# 8cf87e9e-9b56-482e-918c-bacf72c93677    28
# 30197d15-e71a-4801-a3da-2383a4e9a807    27
# 1389e8da-4a5d-4853-968e-053456e0e3b2    27
# 6a4ff888-c096-492e-9c9b-44fbe81a392a    27
#                                         ..
# c6a201aa-cabf-4eaa-a263-4d80057c837c     1
# 3d14d4c7-a718-40b6-91a1-e8175658bce3     1
# 3d109962-8845-4b5c-b9af-94b3b0df1352     1
# 3cd4709b-6b33-4ff0-ae32-140e03f4c70d     1
# fffe8b74-25c8-4504-bc05-f2545760b374     1
# Name: count, Length: 19315, dtype: int64

# %%
df['product_id'].value_counts().head(10)
# Out:
# product_id
# 6e9b539a-77ad-4307-acb5-f558f8b5cc6f    6777
# c1ab2206-9b50-4aaa-9446-f322d0976ea6    3807
# eaaf2b74-b09a-4bf5-b0b2-09021044cab8    3359
# 58fd8edb-60ef-4856-bf1f-644ffc133d12    3206
# 1660a6f2-7ef5-4f47-a4aa-e917f41e014e    2935
# 2e1a3d22-2a05-4b6e-bfd8-4b5d5dab3009    2599
# 25a6c99c-d63c-4697-91ef-744b7879d605    2586
# dbe68f3f-99a8-4ef2-a103-908a6fca244d    2488
# c2e39751-db17-424f-8d71-61ec7ecad424    2232
# d3701c21-709a-4090-bab2-020261ce8a92    2113
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("interactions.csv")
df['dwell_time_ms'].plot(kind='hist',bins=10)
plt.show()

# %%
import matplotlib.pyplot as plt
df['interaction_id'].value_counts().head(20).plot(kind='bar')
plt.show()
