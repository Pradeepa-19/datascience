# %%
#binomial distribution
from scipy.stats import binom
binom.pmf(n=20,k=6,p=0.50)
# Out:
# np.float64(0.036964416503906236)

# %%
from scipy.stats import binom
binom.cdf(k=2,n=5,p=0.5)
# Out:
# np.float64(0.5)

# %%
#normal distribution
import numpy as np

# %%
a=np.random.normal(loc=50,scale=10,size=100)

# %%
a
# Out:
# array([31.57513519, 49.07632907, 50.92944272, 52.77955032, 30.87016129,
#        45.83585539, 32.8421317 , 54.14493657, 52.1852329 , 57.80438471,
#        44.93792058, 61.38344832, 62.83605266, 64.13374204, 40.90355827,
#        67.96527295, 44.28153921, 39.25691322, 62.5396865 , 56.15666116,
#        58.60071627, 64.11206053, 56.90158816, 56.50017453, 43.84796259,
#        62.72634751, 53.50545257, 32.89805705, 50.95843895, 56.13207723,
#        47.37225332, 67.33313734, 36.26580051, 18.76812012, 74.48313266,
#        54.42032996, 55.86907514, 51.82640141, 54.68683468, 48.37652001,
#        40.65199972, 46.8068053 , 42.78678237, 60.44098275, 45.04638288,
#        43.45299743, 32.43795223, 41.89709911, 40.3974873 , 43.84653165,
#        53.28590028, 53.34304661, 45.27158765, 44.27278759, 60.74662982,
#        64.1849589 , 61.44312186, 60.46439658, 47.05729133, 30.57777737,
#        74.99503689, 52.035809  , 47.37234208, 48.88192481, 48.54994681,
#        65.53694857, 54.60482992, 38.28784592, 41.6113209 , 61.81656919,
#        57.14270165, 34.6960485 , 50.79462234, 51.41667549, 62.95246303,
#        41.26564478, 61.73706308, 58.06981276, 55.22658695, 26.78402666,
#        65.06856358, 45.95410006, 54.09695073, 48.19145762, 47.1299578 ,
#        41.45236477, 54.67373384, 46.25809643, 67.58576022, 52.68586079,
#        59.7647317 , 44.6282057 , 27.95172353, 63.24910601, 64.79734638,
#        55.8268532 , 57.83653778, 38.51704634, 48.67978204, 46.83463347])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(a,kde=True)
plt.show()
