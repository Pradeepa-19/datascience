# %%
import pandas as pd
d=pd.read_csv('vct2025_01_partnered_teams.csv')
d
# Out:
#                  team_name    region             league         country  \
# 0              NRG Esports  Americas  VCT Americas 2025   United States
# 1                Sentinels  Americas  VCT Americas 2025   United States
# 2                   Cloud9  Americas  VCT Americas 2025   United States
# 3              100 Thieves  Americas  VCT Americas 2025   United States
# 4                     LOUD  Americas  VCT Americas 2025          Brazil
# 5            FURIA Esports  Americas  VCT Americas 2025          Brazil
# 6            Evil Geniuses  Americas  VCT Americas 2025   United States
# 7                 Leviatan  Americas  VCT Americas 2025           Chile
# 8              KRU Esports  Americas  VCT Americas 2025       Argentina
# 9               G2 Esports  Americas  VCT Americas 2025         Germany
# 10               The Guard  Americas  VCT Americas 2025   United States
# 11           2GAME Esports  Americas  VCT Americas 2025          Brazil
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   team_name        48 non-null     object
#  1   region           48 non-null     object
#  2   league           48 non-null     object
#  3   country          48 non-null     object
#  4   team_type        48 non-null     object
#  5   league_location  48 non-null     object
# dtypes: object(6)
# memory usage: 2.4+ KB

# %%
d.describe()
# Out:
#           team_name    region             league country team_type  \
# count            48        48                 48      48        48
# unique           48         4                  4      20         4
# top     NRG Esports  Americas  VCT Americas 2025   China   Partner
# freq              1        12                 12      12        40
#
#          league_location
# count                 48
# unique                 4
# top     Los Angeles, USA
# freq                  12

# %%
d.shape
# Out:
# (48, 6)

# %%
d.size
# Out:
# 288

# %%
#team count
d['team_name'].nunique()
# Out:
# 48

# %%
d['region'].value_counts()
# Out:
# region
# Americas    12
# EMEA        12
# Pacific     12
# China       12
# Name: count, dtype: int64

# %%
d['country'].value_counts()
# Out:
# country
# China             12
# United States      6
# South Korea        4
# France             3
# Spain              3
# Brazil             3
# Turkey             2
# Japan              2
# Indonesia          2
# Philippines        1
# Thailand           1
# India              1
# Chile              1
# Singapore          1
# Argentina          1
# United Kingdom     1
# Ukraine            1
# Netherlands        1
# Germany            1
# Norway             1
# Name: count, dtype: int64

# %%
d['league'].value_counts()
# Out:
# league
# VCT Americas 2025    12
# VCT EMEA 2025        12
# VCT Pacific 2025     12
# VCT China 2025       12
# Name: count, dtype: int64

# %%
d['team_type'].value_counts()
# Out:
# team_type
# Partner                     40
# Ascension 2024               4
# Ascension 2023               3
# Ascension 2024 Runner-up     1
# Name: count, dtype: int64

# %%
#analyse teams by region
d.groupby('region')['team_name'].count()
# Out:
# region
# Americas    12
# China       12
# EMEA        12
# Pacific     12
# Name: team_name, dtype: int64

# %%
import matplotlib.pyplot as plt
d.groupby('region')['team_name'].count().plot(kind='bar')
plt.show()

# %%
#teams by country
import pandas as pd
d=pd.read_csv('vct2025_01_partnered_teams.csv')
d.groupby('country')['team_name'].count().plot(kind='hist')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
d=pd.read_csv('vct2025_01_partnered_teams.csv')
plt.figure(figsize=(3,3))
d['team_type'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.show()

# %%
#top region
d['region'].value_counts().idxmax()
# Out:
# 'Americas'

# %%
d['country'].value_counts().idxmax()
# Out:
# 'China'

# %%
d['league'].value_counts().idxmax()
# Out:
# 'VCT Americas 2025'

# %%
plt.figure(figsize=(3,3))
d['region'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.show()

# %%
d['region'].mode()[0]
# Out:
# 'Americas'

# %%
d[d['country']=='India']
# Out:
#          team_name   region            league country team_type  \
# 28  Global Esports  Pacific  VCT Pacific 2025   India   Partner
#
#        league_location
# 28  Seoul, South Korea

# %%
d[d['country']=='Germany']
# Out:
#     team_name    region             league  country team_type  \
# 9  G2 Esports  Americas  VCT Americas 2025  Germany   Partner
#
#     league_location
# 9  Los Angeles, USA
