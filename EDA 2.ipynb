# %%
# %pip install pandas
import pandas as pd
df=pd.read_csv("transport-january-2026-csv.csv")
df
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#       Series_reference   Period  Data_value  Suppressed STATUS   UNITS  \
# 0           TPTA.S22IA  1970.12      2771.0         NaN      F  NUMBER
# 1           TPTA.S22IA  1971.12      2076.0         NaN      F  NUMBER
# 2           TPTA.S22IA  1972.12      2037.0         NaN      F  NUMBER
# 3           TPTA.S22IA  1973.12      2101.0         NaN      F  NUMBER
# 4           TPTA.S22IA  1974.12      1282.0         NaN      F  NUMBER
# ...                ...      ...         ...         ...    ...     ...
# 45537       TPTQ.S56ZZ  2024.12   4660781.0         NaN      F  Number
# 45538       TPTQ.S56ZZ  2025.03   4659464.0         NaN      F  Number
# 45539       TPTQ.S56ZZ  2025.06   4606776.0         NaN      F  Number
# 45540       TPTQ.S56ZZ  2025.09   4612946.0         NaN      F  Number
# 45541       TPTQ.S56ZZ  2025.12   4678980.0         NaN      F  Number
#
#        Magnitude          Subject  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45542 entries, 0 to 45541
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Series_reference  45542 non-null  object
#  1   Period            45542 non-null  float64
#  2   Data_value        45501 non-null  float64
#  3   Suppressed        0 non-null      float64
#  4   STATUS            45542 non-null  object
#  5   UNITS             45542 non-null  object
#  6   Magnitude         45542 non-null  int64
#  7   Subject           45542 non-null  object
#  8   Group             45542 non-null  object
#  9   Series_title_1    45542 non-null  object
#  10  Series_title_2    22458 non-null  object
#  11  Series_title_3    0 non-null      float64
#  12  Series_title_4    0 non-null      float64
#  13  Series_title_5    0 non-null      float64
# dtypes: float64(6), int64(1), object(7)
# memory usage: 4.9+ MB

# %%
df.describe()
# Out:
#              Period    Data_value  Suppressed  Magnitude  Series_title_3  \
# count  45542.000000  4.550100e+04         0.0    45542.0             0.0
# mean    2003.483932  1.857272e+05         NaN        0.0             NaN
# std       13.743173  5.959473e+05         NaN        0.0             NaN
# min     1961.010000  0.000000e+00         NaN        0.0             NaN
# 25%     1994.010000  2.770000e+02         NaN        0.0             NaN
# 50%     2004.100000  4.492000e+03         NaN        0.0             NaN
# 75%     2015.060000  2.340300e+04         NaN        0.0             NaN
# max     2026.010000  4.678980e+06         NaN        0.0             NaN
#
#        Series_title_4  Series_title_5
# count             0.0             0.0
# mean              NaN             NaN
# std               NaN             NaN
# min               NaN             NaN
# 25%               NaN             NaN
# 50%               NaN             NaN
# 75%               NaN             NaN
# ...

# %%
df.head()
# Out:
#   Series_reference   Period  Data_value  Suppressed STATUS   UNITS  Magnitude  \
# 0       TPTA.S22IA  1970.12      2771.0         NaN      F  NUMBER          0
# 1       TPTA.S22IA  1971.12      2076.0         NaN      F  NUMBER          0
# 2       TPTA.S22IA  1972.12      2037.0         NaN      F  NUMBER          0
# 3       TPTA.S22IA  1973.12      2101.0         NaN      F  NUMBER          0
# 4       TPTA.S22IA  1974.12      1282.0         NaN      F  NUMBER          0
#
#            Subject                                              Group  \
# 0  Transport - TPT  New and Ex-Oseas Motor Vehicles Registered by ...
# 1  Transport - TPT  New and Ex-Oseas Motor Vehicles Registered by ...
# 2  Transport - TPT  New and Ex-Oseas Motor Vehicles Registered by ...
# 3  Transport - TPT  New and Ex-Oseas Motor Vehicles Registered by ...
# 4  Transport - TPT  New and Ex-Oseas Motor Vehicles Registered by ...
#
#                          Series_title_1 Series_title_2  Series_title_3  \
# ...

# %%
df.tail()
# Out:
#       Series_reference   Period  Data_value  Suppressed STATUS   UNITS  \
# 45537       TPTQ.S56ZZ  2024.12   4660781.0         NaN      F  Number
# 45538       TPTQ.S56ZZ  2025.03   4659464.0         NaN      F  Number
# 45539       TPTQ.S56ZZ  2025.06   4606776.0         NaN      F  Number
# 45540       TPTQ.S56ZZ  2025.09   4612946.0         NaN      F  Number
# 45541       TPTQ.S56ZZ  2025.12   4678980.0         NaN      F  Number
#
#        Magnitude          Subject                                      Group  \
# 45537          0  Transport - TPT  Motor Vehicles Currently Licensed by Type
# 45538          0  Transport - TPT  Motor Vehicles Currently Licensed by Type
# 45539          0  Transport - TPT  Motor Vehicles Currently Licensed by Type
# 45540          0  Transport - TPT  Motor Vehicles Currently Licensed by Type
# 45541          0  Transport - TPT  Motor Vehicles Currently Licensed by Type
#
# ...

# %%
df.columns
# Out:
# Index(['Series_reference', 'Period', 'Data_value', 'Suppressed', 'STATUS',
#        'UNITS', 'Magnitude', 'Subject', 'Group', 'Series_title_1',
#        'Series_title_2', 'Series_title_3', 'Series_title_4', 'Series_title_5'],
#       dtype='object')

# %%
df['Subject'].nunique()
# Out:
# 1

# %%
df['Group'].nunique()
# Out:
# 2

# %%
df['Subject'].value_counts()
# Out:
# Subject
# Transport - TPT    45542
# Name: count, dtype: int64

# %%
df['Group'].value_counts()
# Out:
# Group
# New and Ex-Oseas Motor Vehicles Registered by Type    23084
# Motor Vehicles Currently Licensed by Type             22458
# Name: count, dtype: int64

# %%
df.groupby('Subject')['Data_value'].mean()
# Out:
# Subject
# Transport - TPT    185727.159227
# Name: Data_value, dtype: float64

# %%
df.groupby('Group')['Data_value'].mean()
# Out:
# Group
# Motor Vehicles Currently Licensed by Type             373398.523130
# New and Ex-Oseas Motor Vehicles Registered by Type      3478.460362
# Name: Data_value, dtype: float64

# %%
df['Data_value'].max()
# Out:
# 4678980.0

# %%
df['Data_value'].min()
# Out:
# 0.0

# %%
import matplotlib.pyplot as plt
df['Subject'].value_counts().plot(kind='bar')
plt.show()

# %%
df['Data_value'].hist(bins=20)
plt.show()

# %%
df['Period'].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='Period'>

# %%
df['STATUS'].value_counts().plot(kind='bar')
plt.show()

# %%
df['STATUS'].value_counts().plot(kind='hist')
plt.show()

# %%
df['Period'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.show()

# %%
df['Period'].value_counts().head(10).plot(kind='pie',autopct='%1.1f%%')
plt.show()
